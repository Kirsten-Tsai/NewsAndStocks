# %%
import pandas as pd

# %%
pd.read_csv('./Data/Tesla/Content/AllDataMerged.csv')
# Out:
#      year  week  close_1  close_2  close_3  close_4  close_5      vol_1  \
# 0    2018    23   332.10   342.77   344.78   357.72   358.17  1318.3473
# 1    2018    24   370.83   352.55   362.22   347.51   333.63  1207.3226
# 2    2018    25   333.01   342.00   344.50   349.93   342.95   693.1304
# 3    2018    26   335.07   310.86   310.86   309.16   308.90  1875.9765
# 4    2018    27   318.51   322.47   318.96   316.71   318.87   759.6753
# ..    ...   ...      ...      ...      ...      ...      ...        ...
# 98   2020    15   650.95   709.89   729.83   745.21   753.89  2247.5421
# 99   2020    16   746.36   686.72   732.11   705.63   725.15  1474.6577
# 100  2020    17   798.75   769.12   800.51   781.88   701.32  2068.1442
# 101  2020    18   761.19   768.21   782.58   780.04   819.42  1923.7090
# 102  2020    19   811.29   809.41   790.96   803.33   799.17  1651.9601
#
#          vol_2      vol_3      vol_4      vol_5    percent  compound
# ...
